# %% [markdown]
# ## Lib

# %%
import pandas as pd
import json
import ast
from collections import Counter, defaultdict

# %% [markdown]
# ## Load Data and convert to dataframe

# %%
with open('data-es-activity-coord-clean.json', 'r') as file:
    data = json.load(file)
df = pd.json_normalize(data)
print(df.columns.tolist())
# Out:
# ['inst_numero', 'inst_nom', 'inst_adresse', 'inst_cp', 'inst_com_code', 'inst_com_nom', 'new_code', 'new_name', 'inst_actif', 'inst_etat', 'inst_date_creation', 'inst_date_etat', 'inst_date_valid', 'inst_acc_handi_bool', 'inst_enqu_date', 'inst_obs', 'inst_trans_bool', 'inst_part_bool', 'inst_part_type', 'inst_part_type_filter', 'inst_acc_handi_type', 'inst_trans_type', 'inst_siret', 'inst_uai', 'inst_hs_bool', 'equip_numero', 'equip_nom', 'equip_type_code', 'equip_type_name', 'equip_type_famille', 'equip_etat', 'equip_x', 'equip_y', 'equip_eclair', 'equip_acc_libre', 'equip_conf_bool', 'equip_ouv_public_bool', 'equip_loc_bool', 'equip_saison', 'equip_douche', 'equip_sanit', 'equip_dsp', 'equip_pmr_acc', 'equip_pmr_aire', 'equip_pmr_chem', 'equip_pmr_douche', 'equip_pmr_sanit', 'equip_pmr_trib', 'equip_pmr_vest', 'equip_pshs_aire', 'equip_pshs_chem', 'equip_pshs_sanit', 'equip_pshs_sign', 'equip_pshs_trib', 'equip_pshs_vest', 'equip_homo_date', 'equip_travaux_date', 'equip_erp_cat', 'equip_haut', 'equip_larg', 'equip_long', 'equip_surf', 'equip_piste_nb', 'equip_trib_nb', 'equip_vest_ens', 'equip_vest_sport', 'equip_sae_couloir', 'equip_sae_haut', 'equip_sae_surf', 'equip_bassin_long', 'equip_bassin_larg', 'equip_bassin_surf', 'equip_bassin_min', 'equip_bassin_max', 'equip_piste_long', 'equip_url', 'equip_service_date', 'equip_prop_nom', 'equip_obs', 'equip_conf_type', 'equip_erp_type', 'equip_loc_type', 'equip_travaux_type', 'equip_energie', 'equip_utilisateur', 'equip_pasdetir', 'equip_sol', 'equip_nature', 'equip_service_periode', 'equip_homo_periode', 'equip_travaux_periode', 'equip_prop_type', 'equip_propsec_type', 'equip_gest_type', 'equip_cogest_type', 'equip_pdesi_pdipr', 'equip_rnb', 'equip_aps_code', 'equip_aps_nom', 'equip_aps_json', 'epci_code', 'epci_nom', 'code_bdv', 'lib_bdv', 'arr_code', 'arr_name', 'dep_code', 'dep_code_filled', 'dep_nom', 'aca_nom', 'reg_code', 'reg_nom', 'dens_niveau', 'dens_lib', 'zrr_simp', 'categorie', 'coordonnees.lon', 'coordonnees.lat', 'coordonnees']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322777 entries, 0 to 322776
# Columns: 119 entries, inst_numero to coordonnees
# dtypes: float64(20), object(99)
# memory usage: 293.0+ MB

# %%
df["equip_aps_json"][0]
# Out:
# '[{"activite": "1101", "nom": "Basket-Ball", "discipline": "Basketball", "caracteristiques": {"equip_aps_pratique": ["Activité praticable"], "equip_aps_niveau": "Loisir - Entretien - Remise en forme"}}, {"activite": "3701", "nom": "Handball / Mini hand / Handball de plage", "discipline": "Handball", "caracteristiques": {"equip_aps_pratique": ["Activité praticable"], "equip_aps_niveau": "Loisir - Entretien - Remise en forme"}}, {"activite": "8801", "nom": "Volley-ball / Volley-ball de plage (beach-volley) / Green-Volley", "discipline": "Volleyball", "caracteristiques": {"equip_aps_pratique": ["Activité praticable"], "equip_aps_niveau": "Loisir - Entretien - Remise en forme"}}]'

# %%
# Explode the 'equip_aps_code' and 'equip_aps_nom' columns
df_exploded = df.explode('equip_aps_code').explode('equip_aps_nom')

# Group by 'equip_aps_code' and 'equip_aps_nom' and count the occurrences
equip_aps_counts = df_exploded.groupby(['equip_aps_code', 'equip_aps_nom']).size().reset_index(name='occurrences')

# Sort the results by the count in descending order
equip_aps_counts_sorted = equip_aps_counts.sort_values(by='occurrences', ascending=False)

# Display the sorted results
print(equip_aps_counts_sorted)
# Out:
#                          equip_aps_code  \
# 54086                          ["7901"]
# 22417                          ["2901"]
# 35030                          ["6001"]
# 35878                          ["6201"]
# 8825                           ["1101"]
# ...                                 ...
# 9880   ["1401", "4401", "6604", "4501"]
# 9881   ["1401", "4401", "6604", "4501"]
# 65151                   ["901", "8801"]
# 65152                   ["901", "8801"]
# 1              ["1001", "1002", "8101"]
#
#                                            equip_aps_nom  occurrences
# 54086                                             Tennis        39740
# 22417              Football / Football en salle (Futsal)        36385
# 35030                          Pétanque et jeu provencal        22389
# 35878                                 Randonnée pédestre        16457
# 8825                                         Basket-Ball         9001
# ...                                                  ...          ...
# 9880                                       Boxe Anglaise            1
# 9881   Karaté/Karaté jutsu/Goshin jutsu/Kobudo/Nihon ...            1
# 65151                                    Ballon au poing            1
# 65152  Volley-ball / Volley-ball de plage (beach-voll...            1
# 1             Carabine (hors 300m) / Pistolet / Plateaux            1
#
# [65154 rows x 3 columns]

# %%
def count_noms(df):
    nom_counter = Counter()

    for l_nom in df['equip_aps_nom']:
        if isinstance(l_nom, str):
            try:
                nom_list = ast.literal_eval(l_nom)
            except ValueError:
                nom_list = [l_nom]  # If it's a single string, make it a list
        else:
            nom_list = l_nom if isinstance(l_nom, list) else [l_nom]  # Handle non-list iterables
        
        nom_counter.update(nom_list)

    return nom_counter

# Assuming 'df' is your DataFrame
nom_counts = count_noms(df)

# Get the most common 'nom'
most_common_nom = nom_counts.most_common(1)[0]

print(f"The most common 'nom' is '{most_common_nom[0]}' with {most_common_nom[1]} occurrences.")

# Print all unique 'nom' values and their counts
print("\nAll 'nom' values and their counts:")
for nom, count in nom_counts.items():
    print(f"'{nom}': {count}")

# Total number of unique 'nom' values
print(f"\nTotal number of unique 'nom' values: {len(nom_counts)}")

# %%
# get the equip_aps_code, associated equip_aps_nom and the occurences in the dataset finally sort by most popular

# %%
# if these column are empty delete the corresponding row
print(df.shape)
#df_lat_lon = df.dropna(subset=['coordonnees.lat', 'coordonnees.lon'], how='any')
#df_lat_lon.shape
# Out:
# (322777, 119)

# %%
#row_deleted = df.shape[0] - df_lat_lon.shape[0]
#row_deleted

# %%
def clean_dataframe(df, output_path):
    # Create a copy of the original dataframe
    df_copy = df.copy()
    
    # Get the initial number of rows
    initial_rows = len(df_copy)
    
    # Remove rows where all specified columns are None
    df_copy = df_copy.dropna(subset=['equip_aps_json', 'equip_aps_nom', 'equip_aps_code'], how='all')
    
    # Get the final number of rows
    final_rows = len(df_copy)
    
    # Print the number of rows removed
    print(f"Rows removed: {initial_rows - final_rows}")
    print(f"Rows remaining: {final_rows}")
    
     # Convert the dataframe to a list of dictionaries
    data_list = df_copy.to_dict(orient='records')
     # Save the cleaned dataframe as JSON
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(data_list, f)
    
    print(f"Cleaned dataframe saved to {output_path}")

# %%
# clean_dataframe(df_lat_lon, './data-es-activity-coord-clean.json')

# %%
def count_by_code(c):

    lst_code = []
    count = 0
    for l_code in df['equip_aps_code']:
        code_list = ast.literal_eval(l_code)
        for code in code_list:
            if code == c:
                count += 1
            # if code not in lst_code:
               #lst_code.append(code)
    # len(lst_code), lst_code 
    print(count)

# %%
count_by_code("1101")
# Out:
# 44564

# %%
lst_nom = []

for l_nom in df['equip_aps_nom']:
    #print(l_nom)
    if isinstance(l_nom, str):
        try:
            nom_list = ast.literal_eval(l_nom)
        except ValueError:
            nom_list = [l_nom]  # If it's a single string, make it a list
    else:
        nom_list = l_nom  # If it's already a list, use it as is
    #print(nom_list[1])
    for nom in nom_list:
        if nom not in lst_nom:
           lst_nom.append(nom)
    # lst_nom.append(nom_list)
    #break  # Remove this if you want to process all rows
len(lst_nom), lst_nom
# Out:
# (229,
#  ['Basket-Ball',
#   'Handball / Mini hand / Handball de plage',
#   'Volley-ball / Volley-ball de plage (beach-volley) / Green-Volley',
#   'Spéléologie',
#   'Autres Danses',
#   'Gymnastique Artistique',
#   'Gymnastique volontaire',
#   'Taekwondo / Hapkido / Tang-soo-do / Soo bahk do / Sin moo hapkido / Hapkido jin jung kwan',
#   'Tennis de table',
#   'Activités de forme et de santé',
#   'Pétanque et jeu provencal',
#   'Canyonisme',
#   'Football / Football en salle (Futsal)',
#   'Tennis',
#   'Expression gymnique',
#   'Escalade',
#   'Deltaplane',
#   'Parapente',
#   'Saut',
#   'Musculation',
#   'Badminton, Jeu de volant',
#   'Carabine (hors 300m) / Pistolet / Plateaux',
#   'Dressage',
#   "Saut d'obstacle",
#   'Equitation',
#   'Aikido / Aikibudo / Budo',
#   'Karaté/Karaté jutsu/Goshin jutsu/Kobudo/Nihon Tai-jutsu/Taijitsu/Nambudo/Ninjutsu/Nunchaku/...',
#   'Judo / Jujitsu / Taïso',
#   'Cesta punta/Mains nues/Pala/Chistera (grande, joko garbi)/Paleta/Xare/Frontenis/Pala corta/Rebot',
#   'Escrime (Epée / Fleuret / Sabre )',
#   'Golf',
#   'Sports boules',
#   'Ski alpin (de piste)',
#   'Surf des neiges (snowboard)',
#   'Ballet sur glace / Danse sur glace / Patinage artistique',
#   'Escalade dans les arbres',
#   'Escalade sur PAH',
#   'Baignade loisirs',
#   'Escalade sur Via ferrata/Corda',
#   'Trial',
#   'Dériveur / Multicoques / Courses océaniques / au large / Voile modèle / traditionnelle /match racing',
#   'Planche à Voile',
#   'Motonautisme / Jet hydrojet / Aéroglisseur',
#   'Hockey en salle / Hockey sur gazon',
#   'Rugby à 15 / Rugby à 7',
#   'Aviron',
#   'Billard (Français (carambole),Snooker,Anglais,Américain)',
#   'Twirling bâton',
#   'Plongée subaquatique (Plongée libre)',
#   "Tir à l'arc",
#   'Gymnastique Aérobic',
#   'Gymnastique Rythmique',
#   'Culturisme',
#   'Football Américain / Flag',
#   'Aquagym',
#   'Course sur piste',
#   'Kayak de mer',
#   "Pirogue polynésienne (Va'a)/Pirogue dragon",
#   'Wave-ski',
#   'Boxe Anglaise',
#   "Plongée d'exploration / Photographie subaquatique",
#   'Gymnastique Acrobatique',
#   'Lancer',
#   'Baseball',
#   'Lutte traditionnelle / olympique libre / olympique gréco-romaine /  bretonne / féminine',
#   'Natation course sportive',
#   'Squash',
#   'Formule racer / Vol à moteur / Voltige aérienne/Rallye aérien/Pilotage précision',
#   'Randonnée pédestre',
#   'Kick boxing / Cardio KB / Kick boxing light / KB Défense',
#   'Cerf volant de traction (glisse aérotractée) et kitesurf',
#   'Natation synchronisée',
#   'Plongeon',
#   'Concours complet',
#   'Padel',
#   'Roller acrobatique',
#   'Kendo / Iaïdo / Naginata / Jodo / Sport chanbara',
#   'Ski nordique (de fond)',
#   'Vtt (Cross Country/ Descente/ Trial/ Rallye/ Four Cross) / Vélo trial',
#   'Randonnée équestre',
#   'Danses par Couple (Danses de compétition)',
#   'Ski alpinisme',
#   'Patinage de course',
#   'Pêche au coup en eau douce',
#   'Parachutisme',
#   'Ski nautique classique / Course / à figures libres / nupieds / Kneeboard / Wake-board',
#   'Course et marche sur route (hors stade)',
#   'Boxe thaïlandaise Muay Thaï',
#   'Cross country',
#   'Haltérophilie / Force athlétique',
#   'Hockey sur patins en ligne / Hockey sur patins',
#   'Full contact (boxe américaine)/Light contact/First full/Full défense/Super fight/Semi-contact',
#   'Canoë de randonnée',
#   'Planche à roulettes (Skate)',
#   'Bicross (BMX)',
#   'Tai chi chuan / Chi gong',
#   'Pêche sportive à la mouche et au lancer',
#   'Joutes et sauvetage nautique',
#   'Boules traditionnelles',
#   'Arbalète / Armes anciennes / Bench rest / Silhouettes métalliques / Tir sportif de vitesse',
#   'Tir aux armes réglementaires',
#   'Ballon au poing',
#   'Quad',
#   'Attelage',
#   'Modélisme automobile radio-guidé',
#   'Paintball',
#   'Planeur ULM / Multiaxe / Pendulaire / Paramoteur / Motorisations auxiliaires / Autogire',
#   'Horse - Ball',
#   "Course d'orientation - Pédestre",
#   'Fosse universelle',
#   'Parcours de chasse',
#   'Cyclisme sur piste',
#   'Motocyclisme (course sur route ou sur piste)',
#   "Course d'orientation - Ski",
#   "Course d'orientation - Vtt",
#   'Motocross / Enduro',
#   'Descente',
#   'Rodéo/Freestyle',
#   'Slalom',
#   'Tumbling',
#   'Cyclotourisme',
#   'Bowling',
#   'Marche',
#   'Cible Mobile / Carabine 300m',
#   "Saut à l'élastique",
#   'Trampoline / Double mini-tramp',
#   'Karting',
#   'Sports de quilles',
#   'Sport automobile',
#   'Rugby à 13 / Rugby à 7',
#   'Course en ligne',
#   'Patinage artistique et danse sur roulettes',
#   'Echecs',
#   'Aéromodélisme',
#   'Raft (embarcation gonflable)',
#   'Raquette à neige',
#   'Ski nordique-biathlon',
#   'Traineau à chiens',
#   'Nage en eau vive',
#   'Luge',
#   'Boxe française savate',
#   'Cyclisme en salle',
#   'Cyclocross',
#   'Kayak-polo',
#   'Water-Polo',
#   'Polo',
#   'Cerf volant',
#   'Course sur le plat',
#   'Nage avec palmes',
#   'Aérostation',
#   'Giraviation',
#   'Vol à voile',
#   'Natation en eau libre',
#   'Sauvetage en eau plate',
#   'Equitation western / Equitation camarguaise',
#   'Voile radio commandée',
#   'Hockey subaquatique',
#   "Raid équestre d'endurance",
#   'Plongée en apnée',
#   'Cricket',
#   'Racquetball',
#   'Javelot Tir sur cible',
#   'Jeu de Paume',
#   'Beach soccer',
#   'Longue paume',
#   'Fosse européenne',
#   'Pêche sous marine',
#   'Course camarguaise',
#   'Pêche en mer',
#   'Swing / Disc',
#   'Balle au tambourin',
#   'Bâton',
#   'Surf',
#   'Pentathlon Moderne',
#   'Moto verte',
#   'Curling',
#   'Patinage synchronisé',
#   'Softball',
#   'Téléski nautique',
#   'Hockey sur glace / Ringuette',
#   'Ascensionnel',
#   'Orientation subaquatique',
#   'Modèle réduit',
#   'Triathlon',
#   'Char à voile (Aéroplage)',
#   'Voilier des sables',
#   'Sauvetage côtier/Surfboat',
#   'Sambo',
#   'Chute inversée',
#   'Voltige en planeur',
#   'Compak sporting',
#   'Canne',
#   'Savate défense',
#   "Précision à l'atterrissage",
#   'Chute assis',
#   'Ski pulka',
#   'Char a cerf volant/à glace/à neige/ Kart à voile',
#   'Patinage de vitesse',
#   'Tir sur cible subaquatique',
#   'Duathlon',
#   'Marathon',
#   'Merathon (océan racing)',
#   'Multisports/sport pour tous',
#   'Crocket',
#   'Courte paume',
#   'Stand up Padle',
#   'Course landaise',
#   'Epreuves combinées',
#   'Ski nordique-saut',
#   'Ski artistique sauts',
#   'Sumo',
#   'Expression libre',
#   'Motoball',
#   'Cyclisme sur route/Vélo Couché',
#   'Double dutch',
#   'Parachutisme Voile contact',
#   'Parachutisme Vol relatif',
#   'Parachutisme Voltige',
#   'Ski artistique',
#   'Ski artistique bosses',
#   'Cross canin (Cani-Cross',
#   'Cani VTT',
#   'Ski Joering Canin)',
#   'Cécifoot',
#   'Bobsleigh',
#   'Cheerleading',
#   'Polo-vélo',
#   'Randonnée Roller',
#   'Parachutisme Surf'])

# %%
def count_noms(df):
    nom_counter = Counter()

    for l_nom in df['equip_aps_nom']:
        if isinstance(l_nom, str):
            try:
                nom_list = ast.literal_eval(l_nom)
            except ValueError:
                nom_list = [l_nom]  # If it's a single string, make it a list
        else:
            nom_list = l_nom if isinstance(l_nom, list) else [l_nom]  # Handle non-list iterables
        
        nom_counter.update(nom_list)

    return nom_counter

# Assuming 'df' is your DataFrame
nom_counts = count_noms(df)

# Get the most common 'nom'
most_common_nom = nom_counts.most_common(1)[0]

print(f"The most common 'nom' is '{most_common_nom[0]}' with {most_common_nom[1]} occurrences.")

# Print all unique 'nom' values and their counts
print("\nAll 'nom' values and their counts:")
for nom, count in nom_counts.items():
    print(f"'{nom}': {count}")

# Total number of unique 'nom' values
print(f"\nTotal number of unique 'nom' values: {len(nom_counts)}")
# Out:
# The most common 'nom' is 'Football / Football en salle (Futsal)' with 61356 occurrences.
#
# All 'nom' values and their counts:
# 'Basket-Ball': 44564
# 'Handball / Mini hand / Handball de plage': 34121
# 'Volley-ball / Volley-ball de plage (beach-volley) / Green-Volley': 21272
# 'Spéléologie': 5039
# 'Autres Danses': 11753
# 'Gymnastique Artistique': 6960
# 'Gymnastique volontaire': 13531
# 'Taekwondo / Hapkido / Tang-soo-do / Soo bahk do / Sin moo hapkido / Hapkido jin jung kwan': 1059
# 'Tennis de table': 9339
# 'Activités de forme et de santé': 16757
# 'Pétanque et jeu provencal': 24247
# 'Canyonisme': 1287
# 'Football / Football en salle (Futsal)': 61356
# 'Tennis': 51550
# 'Expression gymnique': 5099
# 'Escalade': 6803
# 'Deltaplane': 794
# 'Parapente': 1485
# 'Saut': 5675
# 'Musculation': 6878
# 'Badminton, Jeu de volant': 12774
# 'Carabine (hors 300m) / Pistolet / Plateaux': 1856
# 'Dressage': 7607
# 'Saut d'obstacle': 6754
# 'Equitation': 11854
# 'Aikido / Aikibudo / Budo': 2029
# 'Karaté/Karaté jutsu/Goshin jutsu/Kobudo/Nihon Tai-jutsu/Taijitsu/Nambudo/Ninjutsu/Nunchaku/...': 4954
# 'Judo / Jujitsu / Taïso': 7865
# 'Cesta punta/Mains nues/Pala/Chistera (grande, joko garbi)/Paleta/Xare/Frontenis/Pala corta/Rebot': 1116
# 'Escrime (Epée / Fleuret / Sabre )': 1084
# 'Golf': 1807
# 'Sports boules': 3946
# 'Ski alpin (de piste)': 441
# 'Surf des neiges (snowboard)': 195
# 'Ballet sur glace / Danse sur glace / Patinage artistique': 193
# 'Escalade dans les arbres': 353
# 'Escalade sur PAH': 717
# 'Baignade loisirs': 7021
# 'Escalade sur Via ferrata/Corda': 239
# 'Trial': 43
# 'Dériveur / Multicoques / Courses océaniques / au large / Voile modèle / traditionnelle /match racing': 2054
# 'Planche à Voile': 931
# 'Motonautisme / Jet hydrojet / Aéroglisseur': 591
# 'Hockey en salle / Hockey sur gazon': 915
# 'Rugby à 15 / Rugby à 7': 4576
# 'Aviron': 559
# 'Billard (Français (carambole),Snooker,Anglais,Américain)': 778
# 'Twirling bâton': 896
# 'Plongée subaquatique (Plongée libre)': 1430
# 'Tir à l'arc': 4023
# 'Gymnastique Aérobic': 1824
# 'Gymnastique Rythmique': 1951
# 'Culturisme': 522
# 'Football Américain / Flag': 248
# 'Aquagym': 2080
# 'Course sur piste': 8289
# 'Kayak de mer': 518
# 'Pirogue polynésienne (Va'a)/Pirogue dragon': 289
# 'Wave-ski': 276
# 'Boxe Anglaise': 2094
# 'Plongée d'exploration / Photographie subaquatique': 507
# 'Gymnastique Acrobatique': 1127
# 'Lancer': 3467
# 'Baseball': 429
# 'Lutte traditionnelle / olympique libre / olympique gréco-romaine /  bretonne / féminine': 1120
# 'Natation course sportive': 2426
# 'Squash': 1394
# 'Formule racer / Vol à moteur / Voltige aérienne/Rallye aérien/Pilotage précision': 517
# 'Randonnée pédestre': 25422
# 'Kick boxing / Cardio KB / Kick boxing light / KB Défense': 388
# 'Cerf volant de traction (glisse aérotractée) et kitesurf': 199
# 'Natation synchronisée': 486
# 'Plongeon': 171
# 'Concours complet': 1763
# 'Padel': 449
# 'Roller acrobatique': 1252
# 'Kendo / Iaïdo / Naginata / Jodo / Sport chanbara': 338
# 'Ski nordique (de fond)': 617
# 'Vtt (Cross Country/ Descente/ Trial/ Rallye/ Four Cross) / Vélo trial': 12177
# 'Randonnée équestre': 5486
# 'Danses par Couple (Danses de compétition)': 1098
# 'Ski alpinisme': 373
# 'Patinage de course': 341
# 'Pêche au coup en eau douce': 3243
# 'Parachutisme': 164
# 'Ski nautique classique / Course / à figures libres / nupieds / Kneeboard / Wake-board': 278
# 'Course et marche sur route (hors stade)': 256
# 'Boxe thaïlandaise Muay Thaï': 332
# 'Cross country': 203
# 'Haltérophilie / Force athlétique': 785
# 'Hockey sur patins en ligne / Hockey sur patins': 467
# 'Full contact (boxe américaine)/Light contact/First full/Full défense/Super fight/Semi-contact': 594
# 'Canoë de randonnée': 3298
# 'Planche à roulettes (Skate)': 3603
# 'Bicross (BMX)': 1959
# 'Tai chi chuan / Chi gong': 1260
# 'Pêche sportive à la mouche et au lancer': 462
# 'Joutes et sauvetage nautique': 44
# 'Boules traditionnelles': 1269
# 'Arbalète / Armes anciennes / Bench rest / Silhouettes métalliques / Tir sportif de vitesse': 605
# 'Tir aux armes réglementaires': 837
# 'Ballon au poing': 78
# 'Quad': 333
# 'Attelage': 1006
# 'Modélisme automobile radio-guidé': 203
# 'Paintball': 369
# 'Planeur ULM / Multiaxe / Pendulaire / Paramoteur / Motorisations auxiliaires / Autogire': 530
# 'Horse - Ball': 1153
# 'Course d'orientation - Pédestre': 748
# 'Fosse universelle': 344
# 'Parcours de chasse': 138
# 'Cyclisme sur piste': 274
# 'Motocyclisme (course sur route ou sur piste)': 183
# 'Course d'orientation - Ski': 16
# 'Course d'orientation - Vtt': 103
# 'Motocross / Enduro': 728
# 'Descente': 843
# 'Rodéo/Freestyle': 494
# 'Slalom': 298
# 'Tumbling': 254
# 'Cyclotourisme': 1110
# 'Bowling': 295
# 'Marche': 258
# 'Cible Mobile / Carabine 300m': 349
# 'Saut à l'élastique': 34
# 'Trampoline / Double mini-tramp': 535
# 'Karting': 358
# 'Sports de quilles': 525
# 'Sport automobile': 287
# 'Rugby à 13 / Rugby à 7': 337
# 'Course en ligne': 408
# 'Patinage artistique et danse sur roulettes': 295
# 'Echecs': 220
# 'Aéromodélisme': 653
# 'Raft (embarcation gonflable)': 412
# 'Raquette à neige': 490
# 'Ski nordique-biathlon': 51
# 'Traineau à chiens': 54
# 'Nage en eau vive': 154
# 'Luge': 49
# 'Boxe française savate': 685
# 'Cyclisme en salle': 116
# 'Cyclocross': 120
# 'Kayak-polo': 240
# 'Water-Polo': 432
# 'Polo': 147
# 'Cerf volant': 83
# 'Course sur le plat': 366
# 'Nage avec palmes': 268
# 'Aérostation': 55
# 'Giraviation': 15
# 'Vol à voile': 191
# 'Natation en eau libre': 237
# 'Sauvetage en eau plate': 76
# 'Equitation western / Equitation camarguaise': 317
# 'Voile radio commandée': 56
# 'Hockey subaquatique': 64
# 'Raid équestre d'endurance': 219
# 'Plongée en apnée': 285
# 'Cricket': 62
# 'Racquetball': 12
# 'Javelot Tir sur cible': 46
# 'Jeu de Paume': 22
# 'Beach soccer': 11
# 'Longue paume': 55
# 'Fosse européenne': 75
# 'Pêche sous marine': 177
# 'Course camarguaise': 107
# 'Pêche en mer': 253
# 'Swing / Disc': 77
# 'Balle au tambourin': 78
# 'Bâton': 42
# 'Surf': 296
# 'Pentathlon Moderne': 19
# 'Moto verte': 31
# 'Curling': 20
# 'Patinage synchronisé': 25
# 'Softball': 58
# 'Téléski nautique': 48
# 'Hockey sur glace / Ringuette': 113
# 'Ascensionnel': 9
# 'Orientation subaquatique': 24
# 'Modèle réduit': 40
# 'Triathlon': 175
# 'Char à voile (Aéroplage)': 87
# 'Voilier des sables': 22
# 'Sauvetage côtier/Surfboat': 68
# 'Sambo': 28
# 'Chute inversée': 5
# 'Voltige en planeur': 8
# 'Compak sporting': 117
# 'Canne': 11
# 'Savate défense': 23
# 'Précision à l'atterrissage': 5
# 'Chute assis': 4
# 'Ski pulka': 7
# 'Char a cerf volant/à glace/à neige/ Kart à voile': 40
# 'Patinage de vitesse': 15
# 'Tir sur cible subaquatique': 14
# 'Duathlon': 4
# 'Marathon': 10
# 'Merathon (océan racing)': 6
# 'Multisports/sport pour tous': 92
# 'Crocket': 9
# 'Courte paume': 5
# 'Stand up Padle': 1
# 'Course landaise': 103
# 'Epreuves combinées': 1
# 'Ski nordique-saut': 35
# 'Ski artistique sauts': 9
# 'Sumo': 17
# 'Expression libre': 3
# 'Motoball': 15
# 'Cyclisme sur route/Vélo Couché': 92
# 'Double dutch': 3
# 'Parachutisme Voile contact': 4
# 'Parachutisme Vol relatif': 4
# 'Parachutisme Voltige': 3
# 'Ski artistique': 15
# 'Ski artistique bosses': 6
# 'Cross canin (Cani-Cross': 3
# 'Cani VTT': 3
# 'Ski Joering Canin)': 3
# 'Cécifoot': 1
# 'Bobsleigh': 3
# 'Cheerleading': 2
# 'Polo-vélo': 3
# 'Randonnée Roller': 1
# 'Parachutisme Surf': 5
#
# Total number of unique 'nom' values: 229
